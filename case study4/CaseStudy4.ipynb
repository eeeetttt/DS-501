# %% [markdown]
# ### Problem 1: Business/Domain Industry Part (20 points)
# As a group, learn about the data science related business/domain industry and research about the current market/community/organization: such as search, social media, advertisement, recommendation and so on. Pick one market/community/organization for further consideration, and design a better service/solution on any data you like, develop a prototype/demo, and prepare a presentation for your idea. Define precisely in the report and briefly in the cells below, what is the business/domain industry problem that your team wants to solve. Why the problem is important to solve? Why you believe you could make a big difference with data science technology. How are you planing to persuade the investors to buy in your idea.

# %% [markdown]
# **Please describe here *briefly*  (please edit this cell)**
#
# 1) What is your business/domain industry problem?
#
# Create a more effective process to identify the right people for promotion within a large multinational company.
#
# 2) Why is the problem important to solve?
#
# The current process involves identifying a set of potential employees eligible for promotion, having them go through a training and evaluation program, and finally promote the eligible employees based on various factors such as training performance, KPI completion, etc. For this process, the final promotions are only announced after the final evaluation period and this leads to delay in transitioning the employees to their new roles. Solving this problem will expedite the promotion cycle.
#
# 3) What is your idea to solve the problem?
#
# Use a classification model to predict whether a potential promotee is eligible for promotion or not at a particular checkpoint before the final evaluation period.
#
# 4) What differences could you make with your data science approach?
#
# By testing with different classification models, we can identify the most effective one for the task at hand and effectively speeds up the promotion cycle based on the list of past employees who have been promoted.
#
#
# 5) Why do you believe the idea deserves the investment of the "Shark Tank"?
#
# Time is money so investing in this idea will increase the company's net profit in the long run. Transition periods tend to be amongst the most difficult and unstable times a company needs to go through so anything that can smooth out the process will have a great positive impact.

# %% [markdown]
# ### Problem 2: Math Part (20 points)

# %% [markdown]
# Define the business/domain industry problem and design the mathematical part/model to solve the problem and develop the solution

# %% [markdown]
# **Insert your answers here**
#
# 1) Mathematical Part/Model Solving the Problem:
#
# 2) Implementation of the Solution

# %% [markdown]
# #### 1. LogisticRegression
#
# ##### a) Mathematical Model
#
# $$
# p(x) = \frac{1}{1+e^{-(\beta_0+\beta_1x)}}
# $$
#
# ##### b) Implementation
#
# we can also write it as:
# $$
# \frac{p(x)}{1-p(x)} = e^{\beta_0+\beta_1x}
# $$
# and
# $$
# ln\frac{p(x)}{1-p(x)} = \beta_0+\beta_1x
# $$
# Since we have multiple explanatory variables, $\beta_0+\beta_1x$ can be revised to $\beta_0+\beta_1x_1+\beta_2x_2+...+\beta_mx_m $

# %% [markdown]
# #### 2. Random Forest
#
# ##### a) Mathematical Model
#
# For each decision tree, Scikit-learn calculates a nodes importance using Gini Importance, assuming only two child nodes (binary tree):
# $$
# ni_j = w_jC_j - w_{left(j)}C_{left(j)} - w_{right(j)}C_{right(j)}
# $$
#
# where
#
# $ni_j=$ the importance of node j
#
# $w_j = $ weighted number of samples reaching node j
#
# $ C_j= $ the impurity value of node j
#
# $left(j) =$ child node from left split on node j
#
# $right(j) =$ child node from right split on node j
#
# The importance of each feature on a decision tree is then calculated as:
#
# $$
# fi_i = \frac{\Sigma_\text{j: node j splits on feature i}ni_j}{\Sigma_{k \in \text{all nodes}}ni_k}
# $$
#
# where
#
# $fi_i=$ the importance of feature i
#
# $ ni_j=$ the importance of node j
#
# These can then be normalized to a value between 0 and 1 by dividing by the sum of all feature importance values:
# $$
# normfi_i = \frac{fi_i}{\Sigma_{j\in\text{all features}}fi_j}
# $$
#
# Then Random Forest:
# $$
# RFfi_i = \frac{\Sigma_{j\in\text{all trees}}normfi_j}{T}
# $$
#
# Where $T =$ total number of trees
#
# ##### b) Implementation
#
# $$
# fi_i = \Sigma_\text{j: node j splits on feature i}S_jC_j
# $$
#
# where
#
# $S_j =$ number of samples reaching node j
#
# $C_j =$ the impurity value of node j
#
# Then
# $$
# normfi_i = \frac{fi_i}{\Sigma_{j\in\text{all features}}fi_j}
# $$
#
# And
# $$
# RFfi_i = \frac{\Sigma_j normfi_{ij}}{\Sigma_{j\in\text{all features,}k\in\text{all trees }}normfi_{jk}}
# $$

# %% [markdown]
# #### 3. Giadient Boosting
#
# ##### a) Mathematical Model
#
# The goal is to find some function $\hat{F}(x)$ that best approximates the output variable y from the values of input variables x.
#
# $$
# {\hat {F}}={\underset {F}{\arg \min }}\,\mathbb {E} _{x,y}[L(y,F(x))]
# $$
#
# gradient boosting method:
#
# $$
# {\hat {F}}(x)=\sum _{i=1}^{M}\gamma _{i}h_{i}(x)+{\mbox{const}}
# $$
#
# ##### b) Implementation
#
# Starting with a model, consisting of a constant function $F_{0}(x)$, and incrementally expands it in a greedy fashion:
# $$
# F_{0}(x)={\underset {\gamma }{\arg \min }}{\sum _{i=1}^{n}{L(y_{i},\gamma )}}
# $$
# $$
# F_{m}(x)=F_{m-1}(x)+{\underset {h_{m}\in {\mathcal {H}}}{\operatorname {arg\,min} }}\left[{\sum _{i=1}^{n}{L(y_{i},F_{m-1}(x_{i})+h_{m}(x_{i}))}}\right]
# $$

# %% [markdown]
# ### Problem 3: Computer Part  (20 points)

# %% [markdown]
# 1) Data Collection
#
# 2) Implement a small demo/prototype/experiment result figures for the "product" of your data science company/organization/community. You could use this demo during the presentation

# %%
# !pip install imblearn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier

from sklearn.tree import DecisionTreeClassifier 
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from typing import List, Tuple, Dict

import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, mean_absolute_error
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import math
# %matplotlib inline

# %% [markdown]
# #### Loading the dataset

# %%
#Loading the data into our dataframe
employee = pd.read_csv('data.csv')

# %%
#Viewing the data
employee.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %% [markdown]
# #### Data Exploration

# %%
#Describing the data
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %% [markdown]
# Note: We can see that 'education' has a lot of missing data and 'previous_year_rating' as well.

# %% [markdown]
# Exploring column 'employee_id'

# %%
#Number of unique employee_id
print("No of unique employee_id: ",employee.employee_id.nunique())
# Out:
# No of unique employee_id:  54808

# %% [markdown]
# We see that 'employee_id' is therefore an unique key for the dataset as it has no repeatation

# %% [markdown]
# Exploring column 'department'

# %%
#Number of unique department
print("No of unique department: ",employee.department.nunique())
print("\nThe unique departments are: ")
print(employee.department.unique())
# Out:
# No of unique department:  9
#
# The unique departments are:
# ['Sales & Marketing' 'Operations' 'Technology' 'Analytics' 'R&D'
#  'Procurement' 'Finance' 'HR' 'Legal']

# %%
#Plotting the count plot of the different departments

plt.figure(figsize=(12,6))
sns.set_theme(style="darkgrid")
sns.countplot(x='department', data=employee)
plt.title("Countplot of different 'departments'")
plt.show()

# %%
#Plotting the count plot of the different departments with hue

plt.figure(figsize=(12,6))
sns.set_theme(style="darkgrid")
sns.countplot(x='department', data=employee, hue='is_promoted')
plt.title("Countplot of different 'departments' based on is_promoted")
plt.show()

# %% [markdown]
# Exploring column 'region'

# %%
#Number of unique region
print("No of unique region: ",employee.region.nunique())
print("\nThe unique region are: ")
print(employee.region.unique())
# Out:
# No of unique region:  34
#
# The unique region are:
# ['region_7' 'region_22' 'region_19' 'region_23' 'region_26' 'region_2'
#  'region_20' 'region_34' 'region_1' 'region_4' 'region_29' 'region_31'
#  'region_15' 'region_14' 'region_11' 'region_5' 'region_28' 'region_17'
#  'region_13' 'region_16' 'region_25' 'region_10' 'region_27' 'region_30'
#  'region_12' 'region_21' 'region_8' 'region_32' 'region_6' 'region_33'
#  'region_24' 'region_3' 'region_9' 'region_18']

# %%
#Plotting the count plot of the different regions

plt.figure(figsize=(20,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='region', data=employee)
plt.xticks(rotation=90)
plt.title("Countplot of 'region'")
plt.show()

# %%
#Plotting the count plot of the different regions with hue

plt.figure(figsize=(20,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='region', data=employee, hue='is_promoted')
plt.xticks(rotation=90)
plt.title("Countplot of 'region' based on 'is_promoted'")
plt.show()

# %% [markdown]
# Exploring column 'education'

# %%
#Number of unique education
print("No of unique education: ",employee.education.nunique())
print("\nThe unique education are: ")
print(employee.education.unique())
# Out:
# No of unique education:  3
#
# The unique education are:
# ["Master's & above" "Bachelor's" nan 'Below Secondary']

# %%
#Plotting the count plot of the different education

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='education', data=employee)
plt.title("Countplot of 'education'")
plt.show()

# %%
#Plotting the count plot of the different education with hue

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='education', data=employee, hue='is_promoted')
plt.title("Countplot of 'education' based on 'is_promoted'")
plt.show()

# %% [markdown]
# Exploring column 'gender'

# %%
#Number of gender department
print("No of unique gender: ",employee.gender.nunique())
print("\nThe unique gender are: ")
print(employee.gender.unique())
# Out:
# No of unique gender:  2
#
# The unique gender are:
# ['f' 'm']

# %%
#Plotting the count plot of the different gender

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='gender', data=employee)
plt.title("Countplot of 'gender'")
plt.show()

# %%
#Plotting the count plot of the different gender based on is_promoted

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='gender', data=employee,hue='is_promoted')
plt.title("Countplot of 'gender' based on 'is_promoted'")
plt.show()

# %% [markdown]
# Exploring column 'recruitment_channel'

# %%
#Number of unique recruitment_channel
print("No of unique recruitment_channel: ",employee.recruitment_channel.nunique())
print("\nThe unique recruitment_channel are: ")
print(employee.recruitment_channel.unique())
# Out:
# No of unique recruitment_channel:  3
#
# The unique recruitment_channel are:
# ['sourcing' 'other' 'referred']

# %%
#Plotting the count plot of the different recruitment_channel

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='recruitment_channel', data=employee)
plt.title("Countplot of 'recruitment_channel'")
plt.show()

# %%
#Plotting the count plot of the different recruitment_channel based on is_promoted

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='recruitment_channel', data=employee,hue='is_promoted')
plt.title("Countplot of 'recruitment_channel' based on 'is_promoted'")
plt.show()

# %% [markdown]
# Exploring column 'no_of_trainings'

# %%
#Number of unique no_of_trainings
print("No of unique no_of_trainings: ",employee.no_of_trainings.nunique())
# Out:
# No of unique no_of_trainings:  10

# %%
#Histogram of the no_of_trainings taken by employee

plt.figure(figsize=(10,6))
sns.set_theme(style="darkgrid")
employee.hist(column='no_of_trainings',bins=20)
plt.title("Histogram of the 'no_of_trainings' taken by employee")
plt.xlabel('no_of_trainings')
plt.ylabel('Count of employee')
plt.show()

# %% [markdown]
# Exploring column 'age'

# %%
#Number of unique age
print("No of unique age: ",employee.age.nunique())
# Out:
# No of unique age:  41

# %%
#Histogram of the age taken by employee

plt.figure(figsize=(10,6))
sns.set_theme(style="darkgrid")
employee.hist(column='age',bins=100)
plt.title("Histogram of employee's age")
plt.xlabel('age')
plt.ylabel('Count of employee')
plt.show()

# %% [markdown]
# Exploring column 'previous_year_rating'

# %%
#Number of unique previous_year_rating
print("No of unique previous_year_rating: ",employee.previous_year_rating.nunique())
print("\nThe unique previous_year_rating are: ")
print(employee.previous_year_rating.unique())
# Out:
# No of unique previous_year_rating:  5
#
# The unique previous_year_rating are:
# [ 5.  3.  1.  4. nan  2.]

# %%
#Plotting the count plot of the different previous_year_rating

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='previous_year_rating', data=employee)
plt.title("Countplot of 'previous_year_rating'")
plt.show()

# %%
#Plotting the count plot of the different previous_year_rating based on is_promoted

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='previous_year_rating', data=employee,hue='is_promoted')
plt.title("Countplot of 'previous_year_rating' based on 'is_promoted'")
plt.show()

# %% [markdown]
# Exploring column 'length_of_service'

# %%
#Number of unique department
print("No of unique length_of_service: ",employee.length_of_service.nunique())
# Out:
# No of unique length_of_service:  35

# %%
#Histogram of the age taken by length_of_service

plt.figure(figsize=(10,6))
sns.set_theme(style="darkgrid")
employee.hist(column='length_of_service',bins=50)
plt.title("Histogram of the employee's length_of_service")
plt.xlabel('length_of_service')
plt.ylabel('Count of employee')
plt.show()

# %% [markdown]
# Exploring column 'KPIs_met >80%'

# %%
#Number of unique department
print("No of unique KPIs_met >80%: ",employee['KPIs_met >80%'].nunique())
print("\nThe unique KPIs_met >80% are: ")
print(employee['KPIs_met >80%'].unique())
# Out:
# No of unique KPIs_met >80%:  2
#
# The unique KPIs_met >80% are:
# [1 0]

# %%
#Plotting the count plot of the different KPIs_met >80%

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='KPIs_met >80%', data=employee)
plt.title("Countplot of 'KPIs_met >80%'")
plt.show()

# %%
#Plotting the count plot of the different KPIs_met >80% based on is_promoted

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='KPIs_met >80%', data=employee,hue='is_promoted')
plt.title("Countplot of 'KPIs_met >80%' based on 'is_promoted'")
plt.show()

# %% [markdown]
# Exploring column 'department'

# %%
#Number of unique department
print("No of unique awards_won?: ",employee['awards_won?'].nunique())
print("\nThe unique awards_won? are: ")
print(employee['awards_won?'].unique())
# Out:
# No of unique awards_won?:  2
#
# The unique awards_won? are:
# [0 1]

# %%
#Plotting the count plot of the different awards_won? based on is_promoted

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='awards_won?', data=employee)
plt.title("Countplot of 'awards_won?'")
plt.show()

# %%
#Plotting the count plot of the different awards_won? based on is_promoted

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='awards_won?', data=employee,hue='is_promoted')
plt.title("Countplot of 'awards_won?' based on 'is_promoted'")
plt.show()

# %% [markdown]
# Exploring column 'avg_training_score'

# %%
#Number of unique avg_training_score
print("No of unique avg_training_score: ",employee.avg_training_score.nunique())
# Out:
# No of unique avg_training_score:  61

# %%
#Histogram of the age taken by employee

plt.figure(figsize=(10,6))
sns.set_theme(style="darkgrid")
employee.hist(column='avg_training_score',bins=100)
plt.title("Histogram of the employee's avg_training_score")
plt.xlabel('avg_training_score')
plt.ylabel('Count of employee')
plt.show()

# %% [markdown]
# Exploring column 'is_promoted'

# %%
#Number of unique department
print("No of unique is_promoted: ",employee.is_promoted.nunique())
print("\nThe unique is_promoted are: ")
print(employee.is_promoted.unique())
# Out:
# No of unique is_promoted:  2
#
# The unique is_promoted are:
# [0 1]

# %%
#Plotting the count plot of the different is_promoted

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='is_promoted', data=employee)
plt.title("Countplot of 'is_promoted'")
plt.show()

# %% [markdown]
# #### Missing Value Analysis

# %%
# Identifying missing value
plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.heatmap(employee.isnull())
plt.title("Missing values in Employee dataset")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Thus there are two missing values:
#     (a) education
#     (b) previous_year_rating

# %%
#Percentage of missing values
print("Percentage of missing value in 'education': ",sum(employee.education.isna())/len(employee)*100,"%")
print("Percentage of missing value in 'previous_year_rating': ",sum(employee.previous_year_rating.isna())/len(employee)*100,"%")
# Out:
# Percentage of missing value in 'education':  4.395343745438622 %
# Percentage of missing value in 'previous_year_rating':  7.524448985549554 %

# %%
#Plotting the count plot of the different education

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='education', data=employee)
plt.title("Countplot of 'education'")
plt.show()

# %%
#Plotting the count plot of the different previous_year_rating

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='previous_year_rating', data=employee)
plt.title("Countplot of 'previous_year_rating'")
plt.show()

# %%
employee.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
employee.corr()
# Out:
#                       employee_id  no_of_trainings       age  \
# employee_id              1.000000        -0.005121  0.000437
# no_of_trainings         -0.005121         1.000000 -0.081278
# age                      0.000437        -0.081278  1.000000
# previous_year_rating     0.004533        -0.063126  0.006008
# length_of_service        0.001274        -0.057275  0.657111
# KPIs_met >80%           -0.002501        -0.045576 -0.025592
# awards_won?              0.008420        -0.007628 -0.008169
# avg_training_score      -0.000586         0.042517 -0.048380
# is_promoted              0.001206        -0.024896 -0.017166
#
#                       previous_year_rating  length_of_service  KPIs_met >80%  \
# employee_id                       0.004533           0.001274      -0.002501
# no_of_trainings                  -0.063126          -0.057275      -0.045576
# age                               0.006008           0.657111      -0.025592
# ...

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(employee.corr(), square=True)

plt.title('Correlation among the attributes')
plt.show()

# %% [markdown]
# We are going to impute 'education' and 'previous_year_rating' both of which are categorical variables

# %%
print("Value counts of 'previous_year_rating' before inputation")
employee.previous_year_rating.value_counts()
# Out:
# Value counts of 'previous_year_rating' before inputation
# 3.0    18618
# 5.0    11741
# 4.0     9877
# 1.0     6223
# 2.0     4225
# Name: previous_year_rating, dtype: int64

# %%
#Imputing 'previous_year_rating'

#'previous_year_rating' is a categorical variable thus replacing missing values with mode.
employee['previous_year_rating'] = employee['previous_year_rating'].replace(np. nan,3.0)

# %%
#Plotting the count plot of the different previous_year_rating after imputation

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='previous_year_rating', data=employee)
plt.title("Countplot of 'previous_year_rating'")
plt.show()

# %%
print("Value counts of 'previous_year_rating' after imputation")
employee.previous_year_rating.value_counts()
# Out:
# Value counts of 'previous_year_rating' after imputation
# 3.0    22742
# 5.0    11741
# 4.0     9877
# 1.0     6223
# 2.0     4225
# Name: previous_year_rating, dtype: int64

# %%
print("Value counts of 'education' before inmputation")
employee.education.value_counts()
# Out:
# Value counts of 'education' before inmputation
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: education, dtype: int64

# %%
def get_encoder_dictionary(df: pd.DataFrame, encode_cols: List[str], **kwargs) -> Dict[str, LabelEncoder]:
    encoders: Dict[str, LabelEncoder] = {}
    
    # For every column we're fitting the Labelencoder with all non null values and save it in the encoders dictionary with the key `column`
    for column in encode_cols:
        l = LabelEncoder(**kwargs)
        non_null_values: List[Any] = df[~pd.isna(df[column])][column].tolist()
        l.fit(non_null_values)
        encoders[column] = l
    
    return encoders

# %%
# Columns to exclude for imputation
exclude_cols = ['employee_id','is_promoted']

def impute_with_model(df: pd.DataFrame,target: str,encoders: Dict[str, LabelEncoder],ax=None) -> pd.DataFrame:

    # Exit condition if there is no null value in target column
    
    if df[pd.isna(df[target])].shape[0] == 0:
        return df
    
    
    
    #model = LogisticRegression(max_iter=200000)
    model = RandomForestClassifier(n_estimators=1000,random_state=1)
    
    
    
    # Columns that're to be used for this model
    include_cols = [x for x in df.columns if x not in exclude_cols]
    
    # Making a copy of the dataframe
    temp = df[include_cols].copy(deep=True)
    temp.dropna(inplace=True)
    
    for c in temp.columns:
        if c in encoders:
            temp[c] = encoders[c].transform(temp[c])
    
    X, y = (temp[[x for x in df.columns if x not in exclude_cols + [target]]], 
            temp[target])
    
    from imblearn.over_sampling import SMOTE
    smote = SMOTE(random_state=1)

    #fit and apply the transform
    X, y = smote.fit_resample(X,y)
    
    


    
    #Testing the performance of the model
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    sns.heatmap(confusion_matrix(y_test, preds), annot=True, fmt='.0f', 
    ax=ax, linewidth=2, cbar=False)
    print("Accuracy score: ",accuracy_score(y_test, preds))
    print("F1 score: ",f1_score(y_test, preds,average='macro'))
    print("Classifcation report score: \n",classification_report(y_test, preds))
        

    # Final training
    model.fit(X, y)
    # Processing the entire dataframe for prediction
    X_new = df[pd.isna(df[target])][X.columns].dropna()
    
    
    # Encoding values for prediction
    for column, encoder in encoders.items():
        if column in X_new.columns:
            X_new[column] = encoder.transform(X_new[column])
    # Making predictions
    preds = model.predict(X_new)
    labels = encoders[target].inverse_transform(preds)
    
    
    # Adding the predictions to respective columns
    idx_preds_mapping: List[Tuple[int, str]] = list(zip(X_new.index.tolist(), labels))
    for idx, p in idx_preds_mapping:
        df.loc[df.index==idx, target] = p
        
    
    return df

# %%
encoder_cols = ['department', 'region', 'gender', 'education', 'recruitment_channel', 'previous_year_rating', 'KPIs_met >80%', 'awards_won?']
encoders = get_encoder_dictionary(employee, encoder_cols)


# Columns that we have to impute
cols_to_impute = 'education'


employee = impute_with_model(employee, cols_to_impute, encoders)
plt.title("Confusion matrix for imputing education")
plt.show()
# Out:
# Accuracy score:  0.8517862012544314
# F1 score:  0.8510891158549542
# Classifcation report score:
#                precision    recall  f1-score   support
#
#            0       0.82      0.71      0.76      7395
#            1       0.98      1.00      0.99      7276
#            2       0.76      0.85      0.80      7331
#
#     accuracy                           0.85     22002
#    macro avg       0.85      0.85      0.85     22002
# weighted avg       0.85      0.85      0.85     22002

# %%
#Plotting the count plot of the different education

plt.figure(figsize=(10,5))
sns.set_theme(style="darkgrid")
sns.countplot(x='education', data=employee)
plt.title("Countplot of 'education'")
plt.show()

# %%
print("Value counts of 'education' after imputation")
employee.education.value_counts()
# Out:
# Value counts of 'education' after imputation
# Bachelor's          38631
# Master's & above    15353
# Below Secondary       824
# Name: education, dtype: int64

# %%
data = employee.copy(deep=True)

for column, encoder in encoders.items():
    data[column] = encoder.transform(data[column])

# %%
#Our dependent column
DEPENDENT = 'is_promoted'

# %%
#Splitting into dependent and independent variable
X = data.drop(['employee_id']+[DEPENDENT], axis=1).copy(deep=True)
y = data[DEPENDENT]

# %%
#Splitting into training-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
#Performing SMOTE for underdsampling
from imblearn.under_sampling import RandomUnderSampler
undersample = RandomUnderSampler(sampling_strategy='majority',random_state=1)

#fit and apply the transform
X_train_smote_u, y_train_smote_u = undersample.fit_resample(X_train, y_train)

# %%
#Performing SMOTE for oversamplinmg
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=1)

#fit and apply the transform
X_train_smote_o, y_train_smote_o = smote.fit_resample(X_train,y_train)

# %%
from collections import Counter
print("Count of 'is_promoted' before SMOTE :", Counter(y_train))
print("Count of 'is_promoted' after SMOTE(Undersampling) :", Counter(y_train_smote_u))

print("Count of 'is_promoted' after SMOTE(Oversampling) :", Counter(y_train_smote_o))
# Out:
# Count of 'is_promoted' before SMOTE : Counter({0: 35105, 1: 3260})
# Count of 'is_promoted' after SMOTE(Undersampling) : Counter({0: 3260, 1: 3260})
# Count of 'is_promoted' after SMOTE(Oversampling) : Counter({1: 35105, 0: 35105})

# %%
performances = []

def show_confusion_matrix(conf_matrix, **kwargs):
    plt.figure(figsize=(7, 7))
    sns.set(font_scale=1.7)
    sns.heatmap(conf_matrix, annot=True, cbar=False, fmt='.0f', **kwargs)
    sns.set(font_scale=1)

def getModelReport(model, X_train, y_train, X_test, y_test, msg=np.nan):

    preds = model.predict(X_test)
    accuracy = accuracy_score(preds, y_test)
    precision = precision_score(preds, y_test)
    recall = recall_score(preds, y_test)
    f1 = f1_score(preds, y_test)
    conf_matrix = confusion_matrix(preds, y_test)
    clf_report = classification_report(preds, y_test)
    model_class = model.__class__.__name__
    
    # Saving the performances
    performances.append(
        [model_class, accuracy, f1, msg]
    )
    
    # Creating Cross validation scores
    kfold_vc = KFold(n_splits=10)
    results = cross_val_score(model, X_train, y_train, cv=kfold_vc)
    
    print('*'*60)
    print('{}'.format(model_class).rjust(40, ' '))
    print('*'*60)
    print('ACCURACY K-Fold:', results.mean())
    #print('ACCURACY:', accuracy)
    print('F1 SCORE:', f1)
    #print('CLASSIFICATION REPORT: ')
    #print(clf_report)
    print('*'*60)
    
    show_confusion_matrix(conf_matrix)
    plt.title('Confusion matrix of {}'.format(model_class))
    plt.show()

# %%
#Logistic Regression without SMOTE
logreg = LogisticRegression(max_iter=10000)
logreg.fit(X_train, y_train)


getModelReport(logreg, X_train, y_train, X_test, y_test)
# Out:
# ************************************************************
#                       LogisticRegression
# ************************************************************
# ACCURACY K-Fold: 0.91729441095877
# F1 SCORE: 0.12475884244372991
# ************************************************************

# %%
#Logistic Regression with SMOTE(Undersampling)
logreg = LogisticRegression(max_iter=10000)
logreg.fit(X_train_smote_u, y_train_smote_u)


getModelReport(logreg, X_train_smote_u, y_train_smote_u, X_test, y_test)
# Out:
# ************************************************************
#                       LogisticRegression
# ************************************************************
# ACCURACY K-Fold: 0.654601226993865
# F1 SCORE: 0.3059801157441757
# ************************************************************

# %%
#Logistic Regression with SMOTE(Oversampling)
logreg = LogisticRegression(max_iter=10000)
logreg.fit(X_train_smote_o, y_train_smote_o)


getModelReport(logreg, X_train_smote_o, y_train_smote_o, X_test, y_test)
# Out:
# ************************************************************
#                       LogisticRegression
# ************************************************************
# ACCURACY K-Fold: 0.6371172197692635
# F1 SCORE: 0.26606538895152193
# ************************************************************

# %%
#RandomForest without SMOTE
rfor = RandomForestClassifier(n_estimators=1000, random_state=1)
rfor.fit(X_train, y_train)


getModelReport(rfor, X_train, y_train, X_test, y_test)
# Out:
# ************************************************************
#                   RandomForestClassifier
# ************************************************************
# ACCURACY K-Fold: 0.9335072205948174
# F1 SCORE: 0.4109149277688603
# ************************************************************

# %%
#RandomForest with SMOTE(Undersampling)
rfor = RandomForestClassifier(n_estimators=1000, random_state=1)
rfor.fit(X_train_smote_u, y_train_smote_u)


getModelReport(rfor, X_train_smote_u, y_train_smote_u, X_test, y_test)
# Out:
# ************************************************************
#                   RandomForestClassifier
# ************************************************************
# ACCURACY K-Fold: 0.7608895705521472
# F1 SCORE: 0.3589296102385107
# ************************************************************

# %%
#RandomForest with SMOTE(Oversampling)
rfor = RandomForestClassifier(n_estimators=1000, random_state=1)
rfor.fit(X_train_smote_o, y_train_smote_o)


getModelReport(rfor, X_train_smote_o, y_train_smote_o, X_test, y_test)
# Out:
# ************************************************************
#                   RandomForestClassifier
# ************************************************************
# ACCURACY K-Fold: 0.9322746047571571
# F1 SCORE: 0.40281329923273657
# ************************************************************

# %%
#GradientBoostingClassifier without SMOTE
grad = GradientBoostingClassifier(random_state=1)
grad.fit(X_train, y_train)

getModelReport(grad, X_train, y_train, X_test, y_test)
# Out:
# ************************************************************
#               GradientBoostingClassifier
# ************************************************************
# ACCURACY K-Fold: 0.937703709803263
# F1 SCORE: 0.43444871091607234
# ************************************************************

# %%
#GradientBoostingClassifier with SMOTE(Undersampling)
grad = GradientBoostingClassifier(random_state=1)
grad.fit(X_train_smote_u, y_train_smote_u)

getModelReport(grad, X_train_smote_u, y_train_smote_u, X_test, y_test)
# Out:
# ************************************************************
#               GradientBoostingClassifier
# ************************************************************
# ACCURACY K-Fold: 0.7693251533742331
# F1 SCORE: 0.35961800818553885
# ************************************************************

# %%
#GradientBoostingClassifier with SMOTE(Oversampling)
grad = GradientBoostingClassifier(random_state=1)
grad.fit(X_train_smote_o, y_train_smote_o)

getModelReport(grad, X_train_smote_o, y_train_smote_o, X_test, y_test)
# Out:
# ************************************************************
#               GradientBoostingClassifier
# ************************************************************
# ACCURACY K-Fold: 0.7887480415895172
# F1 SCORE: 0.3629764065335754
# ************************************************************

# %% [markdown]
# ### Problem 4: Prepare your slides and *Present* it in the class (20 points)
#
# 1) Prepare the slide(s) for the presentation (10 points)
#
# 2) Present it in the class (10 points).
